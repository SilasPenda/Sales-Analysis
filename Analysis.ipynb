# %% [markdown]
# ## Import Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## Read CSV files into Dataframes

# %%
df1 = pd.read_csv('online_retail_I.csv', encoding= 'unicode_escape')
df1.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df = pd.read_csv('online_retail_II.csv', encoding= 'unicode_escape')
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %% [markdown]
# ##### Rename columns to match in both tables

# %%
df.rename(columns = {'Invoice':'InvoiceNo',
                   'Price':'UnitPrice',
                    'Customer ID':'CustomerID'}, inplace=True)
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1    489434    79323P                   PINK CHERRY LIGHTS        12
# 2    489434    79323W                  WHITE CHERRY LIGHTS        12
# 3    489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4    489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2009-12-01 07:45:00       6.95     13085.0  United Kingdom
# 1  2009-12-01 07:45:00       6.75     13085.0  United Kingdom
# 2  2009-12-01 07:45:00       6.75     13085.0  United Kingdom
# 3  2009-12-01 07:45:00       2.10     13085.0  United Kingdom
# 4  2009-12-01 07:45:00       1.25     13085.0  United Kingdom

# %%
# Save data into csv
df.to_csv('online_data.csv', index=False)

# Read new csv into a dataframe
df2 = pd.read_csv('online_data.csv')
df2.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1    489434    79323P                   PINK CHERRY LIGHTS        12
# 2    489434    79323W                  WHITE CHERRY LIGHTS        12
# 3    489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4    489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2009-12-01 07:45:00       6.95     13085.0  United Kingdom
# 1  2009-12-01 07:45:00       6.75     13085.0  United Kingdom
# 2  2009-12-01 07:45:00       6.75     13085.0  United Kingdom
# 3  2009-12-01 07:45:00       2.10     13085.0  United Kingdom
# 4  2009-12-01 07:45:00       1.25     13085.0  United Kingdom

# %%
df1.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## Merge data into single CSV

# %%
all_data = pd.concat([df1,df2])

# Save all_data into new csv
all_data.to_csv('all_data.csv', index=False)

# %% [markdown]
# ## Read New CSV into Dataframe

# %%
all_data = pd.read_csv('all_data.csv')
all_data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## Clean Data!

# %% [markdown]
# ### Drop Irrelevant Rows

# %% [markdown]
# ##### Drop NaN rows

# %%
# Check for NaN rows
nan_df = all_data[all_data.isna().any(axis=1)]
nan_df.head()
# Out:
#      InvoiceNo StockCode                      Description  Quantity  \
# 622     536414     22139                              NaN        56
# 1443    536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444    536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445    536544     21786               POLKADOT RAIN HAT          4
# 1446    536544     21787            RAIN PONCHO RETROSPOT         2
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 622   12/1/2010 11:52       0.00         NaN  United Kingdom
# 1443  12/1/2010 14:32       2.51         NaN  United Kingdom
# 1444  12/1/2010 14:32       2.51         NaN  United Kingdom
# 1445  12/1/2010 14:32       0.85         NaN  United Kingdom
# 1446  12/1/2010 14:32       1.66         NaN  United Kingdom

# %%
# Drop NaN rows
all_data = all_data.dropna()

# %%
# Re-check for NaN rows
nan_df = all_data[all_data.isna().any(axis=1)]
nan_df.head()
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %% [markdown]
# ##### Drop all rows with 'Country' = Unspecified

# %%
# Print all rows with 'Country' == 'Unspecified'
all_data_filtered = all_data[all_data['Country'] == 'Unspecified']
all_data_filtered.head()
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 152712    549687     20685               DOORMAT RED RETROSPOT         2
# 152713    549687     22691             DOORMAT WELCOME SUNRISE         2
# 152714    549687     48116          DOORMAT MULTICOLOUR STRIPE         2
# 152715    549687     21213         PACK OF 72 SKULL CAKE CASES        24
# 152716    549687     21977  PACK OF 60 PINK PAISLEY CAKE CASES        24
#
#             InvoiceDate  UnitPrice  CustomerID      Country
# 152712  4/11/2011 13:29       7.95     12363.0  Unspecified
# 152713  4/11/2011 13:29       7.95     12363.0  Unspecified
# 152714  4/11/2011 13:29       7.95     12363.0  Unspecified
# 152715  4/11/2011 13:29       0.55     12363.0  Unspecified
# 152716  4/11/2011 13:29       0.55     12363.0  Unspecified

# %%
# Drop all rows with 'Country' == 'Unspecified'
all_data.drop(all_data[all_data['Country'] == 'Unspecified'].index, inplace=True)

# Print all rows with 'Country' == 'Unspecified'
all_data_filtered = all_data[all_data['Country'] == 'Unspecified']
all_data_filtered.head()
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %% [markdown]
# ##### Drop all rows with 'UnitPrice' == 0.0

# %%
# Print all rows with 'UnitPrice' == 0.0
all_data_filtered2 = all_data[all_data['UnitPrice'] == 0.0]
all_data_filtered2.head()
# Out:
#       InvoiceNo StockCode                       Product  Quantity  \
# 9302     537197     22841  ROUND CAKE TIN VINTAGE GREEN         1
# 33576    539263     22580  ADVENT CALENDAR GINGHAM SACK         4
# 40089    539722     22423      REGENCY CAKESTAND 3 TIER        10
# 47068    540372     22090       PAPER BUNTING RETROSPOT        24
# 47070    540372     22553        PLASTERS IN TIN SKULLS        24
#
#               InvoiceDate  UnitPrice  CustomerID         Country  Hour  \
# 9302  2010-12-05 14:02:00        0.0     12647.0         Germany    14
# 33576 2010-12-16 14:36:00        0.0     16560.0  United Kingdom    14
# 40089 2010-12-21 13:45:00        0.0     14911.0            EIRE    13
# 47068 2011-01-06 16:41:00        0.0     13081.0  United Kingdom    16
# 47070 2011-01-06 16:41:00        0.0     13081.0  United Kingdom    16
#
#           Month  Year  Sales
# 9302   December  2010    0.0
# 33576  December  2010    0.0
# 40089  December  2010    0.0
# ...

# %%
# Drop all rows with 'UnitPrice' == 0.0
all_data.drop(all_data[all_data['UnitPrice'] == 0.0].index, inplace=True)

# Print all rows with 'UnitPrice' == 0.0
all_data_filtered2 = all_data[all_data['UnitPrice'] == 0.0]
all_data_filtered2.head()
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Product, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, Hour, Month, Year, Sales]
# Index: []

# %% [markdown]
# ##### Convert columns to Integers

# %%
# Make 'Quantity' an Integer
all_data['Quantity'] = pd.to_numeric(all_data['Quantity'])
# Make 'Price Each' a Float
all_data['UnitPrice'] = pd.to_numeric(all_data['UnitPrice'])

# %% [markdown]
# ##### Add relevant columns

# %%
# Convert 'InvoiceDate' column to datetime format
all_data['InvoiceDate']=pd.to_datetime(all_data['InvoiceDate'])
all_data.head()
# Out:
#   InvoiceNo StockCode                              Product  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Hour     Month  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom     8  December
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     8  December
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom     8  December
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     8  December
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     8  December
#
#    Year  Sales
# 0  2010  15.30
# 1  2010  20.34
# 2  2010  22.00
# 3  2010  20.34
# ...

# %%
# Add Hour, Month, & Year columns
all_data['Hour'] = pd.to_datetime(all_data['InvoiceDate'], format= '%Y-%m-%d %H:%M:%S').dt.hour
all_data['Month'] = pd.to_datetime(all_data['InvoiceDate'], format= '%Y-%m-%d %H:%M:%S').dt.month_name()
all_data['Year'] = pd.to_datetime(all_data['InvoiceDate'], format= '%Y-%m-%d %H:%M:%S').dt.year
all_data.head()
# Out:
#   InvoiceNo StockCode                              Product  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Hour     Month  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom     8  December
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     8  December
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom     8  December
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     8  December
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     8  December
#
#    Year  Sales
# 0  2010  15.30
# 1  2010  20.34
# 2  2010  22.00
# 3  2010  20.34
# ...

# %%
# Add Sales column
all_data['Sales'] = all_data['Quantity'] * all_data['UnitPrice']
all_data.head()
# Out:
#   InvoiceNo StockCode                              Product  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Hour     Month  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom     8  December
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     8  December
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom     8  December
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     8  December
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     8  December
#
#    Year  Sales
# 0  2010  15.30
# 1  2010  20.34
# 2  2010  22.00
# 3  2010  20.34
# ...

# %% [markdown]
# ### Question 1: What is the best sales month and how much was earned that month?

# %%
all_data['Month'] = pd.Categorical(all_data['Month'], ordered=True, categories= ['January', 'February', 'March', 'April','May','June', 'July', 'August','September', 'October', 'November', 'December'])
all_data.pivot_table(index='Month', values='Sales', aggfunc='sum')
# Out:
#                  Sales
# Month
# January    1481103.312
# February   1362491.886
# March      1795925.701
# April      1411880.004
# May        1854721.350
# June       1787114.670
# July       1708475.962
# August     1818930.400
# September  2641946.095
# October    2914196.960
# November   3399393.832
# December   2762134.200

# %%
group = all_data.groupby('Month').sum()

plt.figure(figsize=(8,5))
Month = [Month for Month, all_data in all_data.groupby('Month')] # This arranges the months in the right order
plt.title('Best Sales Month', fontdict={'fontweight':'bold', 'fontsize':18})
plt.bar(Month, group['Sales'])
plt.xticks(Month, rotation='vertical', size=10)
plt.ylabel('Sales ($)')
plt.xlabel('Month')
plt.ticklabel_format(useOffset=False, style='plain', axis='y') #Make value on y axis to be plain and not exponential

plt.show()

# %% [markdown]
# ### What country has the highest number of sales?

# %%
all_data.pivot_table(index='Country', values='Sales', aggfunc='sum')
# Out:
#                              Sales
# Country
# Australia             3.042063e+05
# Austria               3.333192e+04
# Bahrain               1.902770e+03
# Belgium               1.044854e+05
# Brazil                2.555470e+03
# Canada                8.549420e+03
# Channel Islands       6.153990e+04
# Cyprus                3.710903e+04
# Czech Republic        1.415440e+03
# Denmark               8.450923e+04
# EIRE                  8.287868e+05
# European Community    2.583500e+03
# Finland               5.184119e+04
# France                5.232175e+05
# Germany               6.396868e+05
# Greece                2.370601e+04
# Iceland               9.943320e+03
# Israel                1.718790e+04
# Italy                 4.756986e+04
# Japan                 7.911720e+04
# Korea                 9.498200e+02
# Lebanon               3.387760e+03
# Lithuania             8.214800e+03
# Malta                 7.697690e+03
# Netherlands           8.331865e+05
# ...

# %%
group = all_data.groupby('Country').sum()

plt.figure(figsize=(8,5))
Country = [Country for Country, all_data in all_data.groupby('Country')] # This arranges the countries in the right order
plt.title('Best Sales Country', fontdict={'fontweight':'bold', 'fontsize':18})
plt.bar(Country, group['Sales'])
plt.xticks(Country, rotation='vertical', size=10)
plt.ylabel('Sales ($)')
plt.xlabel('Country')
plt.ticklabel_format(useOffset=False, style='plain', axis='y') #Make value on y axis to be plain and not exponential
 
plt.show()

# %%
# Adjust y-axis range to make chart look better. NB: UK sales is higher than the limit set on the axis 

group = all_data.groupby('Country').sum()

plt.figure(figsize=(8,5))
Country = [Country for Country, all_data in all_data.groupby('Country')] # This arranges the countries in the right order
plt.title('Best Sales Country', fontdict={'fontweight':'bold', 'fontsize':18})
plt.bar(Country, group['Sales'])
plt.xticks(Country, rotation='vertical', size=10)
plt.ylabel('Sales ($)')
plt.xlabel('Country')
plt.ticklabel_format(useOffset=False, style='plain', axis='y') #Make value on y axis to be plain and not exponential
 
plt.ylim([1.403900e+02, 2.057430e+06]) # This sets y-axis range

plt.show()

# %% [markdown]
# ### Question 3: What time should we display advertisements to maximize likelihood of customers buying product?

# %%
hours = [hour for hour, df in all_data.groupby('Hour')] # This arranges the hours in the right order

plt.plot(hours, all_data.groupby(['Hour']).count()) #Count number of rows by each hour

plt.xticks(hours)
plt.xlabel('Hour')
plt.ylabel('Number of Orders')
plt.grid()
plt.show()

# My recommendation is advertisements should be displayed around 12pm

# %% [markdown]
# ### Question 4: What products are most often sold together?

# %%
all_data.rename(columns={'Description':'Product'}, inplace=True)
all_data.head()
# Out:
#   InvoiceNo StockCode                              Product  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Hour     Month  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom     8  December
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     8  December
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom     8  December
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     8  December
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     8  December
#
#    Year  Sales
# 0  2010  15.30
# 1  2010  20.34
# 2  2010  22.00
# 3  2010  20.34
# ...

# %%
df = all_data[all_data['InvoiceNo'].duplicated(keep=False)] # This creates a dataframe and stores all duplicated 'InvoiceNo' and keeps them all

# Create a new column called 'Grouped' to store the products sold together
df['Grouped'] = df.groupby('InvoiceNo')['Product'].transform(lambda x: ','.join(x))
# Drop duplicate 'Order ID'
df = df[['InvoiceNo', 'Grouped']].drop_duplicates()
df.head()
# Out:
# C:\Users\sapen\AppData\Local\Temp/ipykernel_4720/4004373124.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped'] = df.groupby('InvoiceNo')['Product'].transform(lambda x: ','.join(x))
#    InvoiceNo                                            Grouped
# 0     536365  WHITE HANGING HEART T-LIGHT HOLDER,WHITE METAL...
# 7     536366  HAND WARMER UNION JACK,HAND WARMER RED POLKA D...
# 9     536367  ASSORTED COLOUR BIRD ORNAMENT,POPPY'S PLAYHOUS...
# 21    536368  JAM MAKING SET WITH JARS,RED COAT RACK PARIS F...
# 25    536369  BATH BUILDING BLOCK WORD,BATH BUILDING BLOCK W...

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in df['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2))) # This counts the 2 products most often sold together.
for key, value in count.most_common(10):
    print(key, value)
# Out:
# ('KEY FOB ', 'KEY FOB ') 5198
# ('WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE HANGING HEART T-LIGHT HOLDER') 2707
# ('KEY FOB ', ' BACK DOOR ') 2436
# ('FRENCH BLUE METAL DOOR SIGN', 'FRENCH BLUE METAL DOOR SIGN') 2414
# ('KEY FOB ', ' SHED') 2413
# ('REGENCY CAKESTAND 3 TIER', 'REGENCY CAKESTAND 3 TIER') 2168
# ('JUMBO BAG RED RETROSPOT', 'JUMBO BAG RED RETROSPOT') 1873
# ('KEY FOB ', ' FRONT  DOOR ') 1817
# ('GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER') 1729
# ('ASSORTED COLOUR BIRD ORNAMENT', 'ASSORTED COLOUR BIRD ORNAMENT') 1728

# %% [markdown]
# ### Question 5:  What product sold the most?

# %%
# Plotting the products sold the most on a chart will not be visible enough because there are too many producst sold.

# Create a pivot table for the sum of quntity of products ordered and sort them by 'Quantity' in descending order
quantity_ordered = all_data.pivot_table(index='Product', values='Quantity', aggfunc='sum')
top_products = quantity_ordered.sort_values(by='Quantity', ascending=False) # Sort 'Products' in descending order by 'Quantity'
top_products.head()
# Out:
#                                     Quantity
# Product
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     160704
# WHITE HANGING HEART T-LIGHT HOLDER    124148
# JUMBO BAG RED RETROSPOT               119630
# ASSORTED COLOUR BIRD ORNAMENT         114704
# BROCADE RING PURSE                     93350

# %%
# Store sorted products in dataframe
quantitydf = top_products.reset_index()

# Store top 20 products in dataframe
quantitydf_20 = quantitydf.iloc[0:20]
quantitydf_20
# Out:
#                                 Product  Quantity
# 0     WORLD WAR 2 GLIDERS ASSTD DESIGNS    160704
# 1    WHITE HANGING HEART T-LIGHT HOLDER    124148
# 2               JUMBO BAG RED RETROSPOT    119630
# 3         ASSORTED COLOUR BIRD ORNAMENT    114704
# 4                   BROCADE RING PURSE      93350
# 5    PACK OF 60 PINK PAISLEY CAKE CASES     79118
# 6       PACK OF 72 RETROSPOT CAKE CASES     79103
# 7           60 TEATIME FAIRY CAKE CASES     70540
# 8               MINI PAINT SET VINTAGE      69220
# 9            PACK OF 12 LONDON TISSUES      63333
# 10                 SMALL POPCORN HOLDER     61798
# 11            ASSORTED COLOURS SILK FAN     61293
# 12                       POPCORN HOLDER     61008
# 13      VICTORIAN GLASS HANGING T-LIGHT     58826
# 14               RED  HARMONICA IN BOX      57129
# 15  COLOUR GLASS T-LIGHT HOLDER HANGING     54467
# 16                   RABBIT NIGHT LIGHT     54188
# 17          PACK OF 72 SKULL CAKE CASES     53051
# ...

# %%
quantitydf_20_asc = quantitydf_20.sort_values(by='Quantity', ascending=True) # Sort 'Products' in ascending order by 'Quantity'
quantitydf_20_asc
# Out:
#                                 Product  Quantity
# 19       72 SWEETHEART FAIRY CAKE CASES     46999
# 18                 JUMBO BAG STRAWBERRY     52372
# 17          PACK OF 72 SKULL CAKE CASES     53051
# 16                   RABBIT NIGHT LIGHT     54188
# 15  COLOUR GLASS T-LIGHT HOLDER HANGING     54467
# 14               RED  HARMONICA IN BOX      57129
# 13      VICTORIAN GLASS HANGING T-LIGHT     58826
# 12                       POPCORN HOLDER     61008
# 11            ASSORTED COLOURS SILK FAN     61293
# 10                 SMALL POPCORN HOLDER     61798
# 9            PACK OF 12 LONDON TISSUES      63333
# 8               MINI PAINT SET VINTAGE      69220
# 7           60 TEATIME FAIRY CAKE CASES     70540
# 6       PACK OF 72 RETROSPOT CAKE CASES     79103
# 5    PACK OF 60 PINK PAISLEY CAKE CASES     79118
# 4                   BROCADE RING PURSE      93350
# 3         ASSORTED COLOUR BIRD ORNAMENT    114704
# 2               JUMBO BAG RED RETROSPOT    119630
# ...

# %%
plt.bar(quantitydf_20_asc['Product'], quantitydf_20_asc['Quantity'])
plt.xticks(quantitydf_20_asc['Product'], rotation='vertical', size=8)
plt.ylabel('Quantity Ordered')
plt.xlabel('Product Name')
plt.ticklabel_format(useOffset=False, style='plain', axis='y') #Make value on y axis to be plain and not exponential
plt.show()
